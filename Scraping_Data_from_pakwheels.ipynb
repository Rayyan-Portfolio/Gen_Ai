# %% [markdown]
# <a href="https://colab.research.google.com/github/Rayyan-Portfolio/Gen_Ai/blob/main/Scraping_Data_from_pakwheels.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import json
import re
import time
import csv

# Base URL for PakWheels used cars
base_url = "https://www.pakwheels.com/used-cars/"

# Headers to mimic a browser visit
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

# Function to extract car listing links
def get_car_links():
    response = requests.get(base_url, headers=headers)
    soup = BeautifulSoup(response.text, "html.parser")

    car_links = set()  # Use a set to store unique links

    for link in soup.find_all("a"):
        href = link.get("href", "")
        if "/used-cars/" in href and "-for-sale-in-" in href:
            full_link = "https://www.pakwheels.com" + href
            car_links.add(full_link)

    return list(car_links)

# Function to extract car details from a listing
def scrape_car_details(car_url):
    response = requests.get(car_url, headers=headers)
    soup = BeautifulSoup(response.text, "html.parser")

    script_tag = soup.find("script", {"type": "application/ld+json"})

    if script_tag:
        try:
            car_data = json.loads(script_tag.string)

            location_text = car_data.get("description", "N/A")

            # Extract price using regex (PKR followed by a number)
            price_match = re.search(r"PKR\s([\d\.]+)\s*lacs?", location_text)
            price_lacs = price_match.group(1) if price_match else "N/A"
            price_pkr = str(int(float(price_lacs) * 100000)) if price_lacs != "N/A" else "N/A"

            car_details = {
                "Brand": car_data.get("brand", {}).get("name", "N/A"),
                "Model": car_data.get("name", "N/A"),
                "Year": car_data.get("modelDate", "N/A"),
                "Fuel Type": car_data.get("fuelType", "N/A"),
                "Transmission": car_data.get("vehicleTransmission", "N/A"),
                "Engine Capacity": car_data.get("vehicleEngine", {}).get("engineDisplacement", "N/A"),
                "Mileage": car_data.get("mileageFromOdometer", "N/A"),
                "Condition": car_data.get("itemCondition", "N/A"),
                "Price (Lacs)": price_lacs if price_lacs != "N/A" else "",
                "Price (PKR)": price_pkr if price_pkr != "N/A" else "",
                "Currency": "PKR" if price_lacs != "N/A" else "",
                "Location": location_text.split("for sale in")[-1].strip(),
                "Image URL": car_data.get("image", "N/A"),
                "Listing URL": car_data.get("offers", {}).get("url", car_url),
            }

            # Remove N/A fields
            car_details = {k: v for k, v in car_details.items() if v != "N/A"}

            print("\nScraped Car Details:")
            for key, value in car_details.items():
                print(f"{key}: {value}")

            return car_details

        except json.JSONDecodeError:
            print(f"Error parsing JSON for {car_url}")
            return None
    else:
        print(f"No structured JSON found for {car_url}")
        return None

# Get car links
car_links = get_car_links()

print(f"Total unique car listings found: {len(car_links)}")

# Prepare CSV file
csv_filename = "scraped_cars.csv"
csv_headers = ["Brand", "Model", "Year", "Fuel Type", "Transmission", "Engine Capacity", "Mileage",
               "Condition", "Price (Lacs)", "Price (PKR)", "Currency", "Location", "Image URL", "Listing URL"]

# Open CSV file and write headers
with open(csv_filename, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.DictWriter(file, fieldnames=csv_headers)
    writer.writeheader()

    # Loop through each car listing and scrape details
    for car_url in car_links:
        print(f"\nScraping: {car_url}")
        car_info = scrape_car_details(car_url)

        if car_info:
            # Write car details to CSV
            writer.writerow(car_info)

        time.sleep(2)

print(f"\n✅ Data saved to {csv_filename}")
# Out:
# Total unique car listings found: 24
#
# Scraping: https://www.pakwheels.com/used-cars/united-bravo-2021-for-sale-in-rawalpindi-9784405
#
# Scraped Car Details:
# Model: United Bravo Base Grade  2021 for sale in Rawalpindi
# Price (Lacs): 13.0
# Price (PKR): 1300000
# Currency: PKR
# Location: United Bravo Base Grade  2021  Used for sale  in Rawalpindi for PKR 13.0 lacs <span></span>. Buy this 800 cc, White 35165 KM Driven, Manual Car. Contact Seller Now!
# Listing URL: https://www.pakwheels.com/used-cars/united-bravo-2021-for-sale-in-rawalpindi-9784405
#
# Scraping: https://www.pakwheels.com/used-cars/toyota-raize-2020-for-sale-in-gujranwala-9803834
#
# Scraped Car Details:
# Model: Toyota Raize XS 2020 for sale in Gujranwala
# Price (Lacs): 49.0
# Price (PKR): 4900000
# Currency: PKR
# Location: Toyota Raize XS 2020  Used for sale  in Gujranwala for PKR 49.0 lacs <span></span>. Buy this 1000 cc, Silver 98000 KM Driven, Automatic Car. Contact Seller Now!
# Listing URL: https://www.pakwheels.com/used-cars/toyota-raize-2020-for-sale-in-gujranwala-9803834
#
# Scraping: https://www.pakwheels.com/used-cars/toyota-yaris-hatchback-2021-for-sale-in-lahore-9803867
#
# Scraped Car Details:
# Model: Toyota Yaris Hatchback G 2021 for sale in Lahore
# Price (Lacs): 53.0
# Price (PKR): 5300000
# Currency: PKR
# Location: Toyota Yaris Hatchback G 2021  Used for sale  in Lahore for PKR 53.0 lacs <span></span>. Buy this 1500 cc, Silver 15931 KM Driven, Automatic Car. Contact Seller Now!
# Listing URL: https://www.pakwheels.com/used-cars/toyota-yaris-hatchback-2021-for-sale-in-lahore-9803867
#
# Scraping: https://www.pakwheels.com/used-cars/toyota-corolla-2020-for-sale-in-islamabad-9267455
#
# Scraped Car Details:
# Model: Toyota Corolla Hybrid WxB 2020 for sale in Islamabad
# Price (Lacs): 80.0
# Price (PKR): 8000000
# Currency: PKR
# Location: Toyota Corolla Hybrid WxB 2020  Used for sale  in Islamabad for PKR 80.0 lacs <span></span>. Buy this 1800 cc, White 80000 KM Driven, Automatic Car. Contact Seller Now!
# Listing URL: https://www.pakwheels.com/used-cars/toyota-corolla-2020-for-sale-in-islamabad-9267455
#
# Scraping: https://www.pakwheels.com/used-cars/suzuki-swift-2013-for-sale-in-islamabad-9421815
#
# Scraped Car Details:
# Model: Suzuki Swift XG 1.2 2013 for sale in Islamabad
# Price (Lacs): 29.0
# Price (PKR): 2900000
# Currency: PKR
# Location: Suzuki Swift XG 1.2 2013  Used for sale  in Islamabad for PKR 29.0 lacs <span></span>. Buy this 1200 cc, Silver 56000 KM Driven, Automatic Car. Contact Seller Now!
# Listing URL: https://www.pakwheels.com/used-cars/suzuki-swift-2013-for-sale-in-islamabad-9421815
#
# Scraping: https://www.pakwheels.com/used-cars/suzuki-mehran-2009-for-sale-in-karachi-9803837
#
# Scraped Car Details:
# Model: Suzuki Mehran VXR 2009 for sale in Karachi
# Price (Lacs): 9.5
# Price (PKR): 950000
# Currency: PKR
# Location: Suzuki Mehran VXR 2009  Used for sale  in Karachi for PKR 9.5 lacs <span></span>. Buy this 800 cc, Blue 43974 KM Driven, Manual Car. Contact Seller Now!
# Listing URL: https://www.pakwheels.com/used-cars/suzuki-mehran-2009-for-sale-in-karachi-9803837
#
# Scraping: https://www.pakwheels.com/used-cars/hyundai-santro-2003-for-sale-in-karachi-9620942
#
# Scraped Car Details:
# Model: Hyundai Santro Exec 2003 for sale in Karachi
# Price (Lacs): 9.0
# Price (PKR): 900000
# Currency: PKR
# Location: Hyundai Santro Exec 2003  Used for sale  in Karachi for PKR 9.0 lacs <span></span>. Buy this 1000 cc, Black 110799 KM Driven, Manual Car. Contact Seller Now!
# Listing URL: https://www.pakwheels.com/used-cars/hyundai-santro-2003-for-sale-in-karachi-9620942
#
# Scraping: https://www.pakwheels.com/used-cars/toyota-vitz-2000-for-sale-in-rawalpindi-9745688
#
# Scraped Car Details:
# Model: Toyota Vitz FL 1.0 2000 for sale in Rawalpindi
# Price (Lacs): 18.0
# Price (PKR): 1800000
# Currency: PKR
# Location: Toyota Vitz FL 1.0 2000  Used for sale  in Rawalpindi for PKR 18.0 lacs <span></span>. Buy this 1000 cc, Silver 294569 KM Driven, Automatic Car. Contact Seller Now!
# Listing URL: https://www.pakwheels.com/used-cars/toyota-vitz-2000-for-sale-in-rawalpindi-9745688
#
# Scraping: https://www.pakwheels.com/used-cars/nissan-note-2019-for-sale-in-islamabad-9718879
#
# Scraped Car Details:
# Model: Nissan Note e-Power X V Selection 2019 for sale in Islamabad
# Price (Lacs): 44.5
# Price (PKR): 4450000
# Currency: PKR
# Location: Nissan Note e-Power X V Selection 2019  Used for sale  in Islamabad for PKR 44.5 lacs <span></span>. Buy this 1200 cc, Black 104000 KM Driven, Automatic Car. Contact Seller Now!
# Listing URL: https://www.pakwheels.com/used-cars/nissan-note-2019-for-sale-in-islamabad-9718879
#
# Scraping: https://www.pakwheels.com/used-cars/honda-civic-2011-for-sale-in-lahore-9707084
#
# Scraped Car Details:
# Model: Honda Civic VTi Oriel Prosmatec 1.8 i-VTEC 2011 for sale in Lahore
# Price (Lacs): 27.5
# Price (PKR): 2750000
# Currency: PKR
# Location: Honda Civic VTi Oriel Prosmatec 1.8 i-VTEC 2011  Used for sale  in Lahore for PKR 27.5 lacs <span></span>. Buy this 1800 cc, Black 116843 KM Driven, Automatic Car. Contact Seller Now!
# Listing URL: https://www.pakwheels.com/used-cars/honda-civic-2011-for-sale-in-lahore-9707084
#
# Scraping: https://www.pakwheels.com/used-cars/daihatsu-tanto-2021-for-sale-in-karachi-9803858
#
# Scraped Car Details:
# Model: Daihatsu Tanto 2021 for sale in Karachi
# Price (Lacs): 30.4
# Price (PKR): 3040000
# Currency: PKR
# Location: Daihatsu Tanto 2021  Used for sale  in Karachi for PKR 30.4 lacs <span></span>. Buy this 660 cc, Pink 73597 KM Driven, Automatic Car. Contact Seller Now!
# Listing URL: https://www.pakwheels.com/used-cars/daihatsu-tanto-2021-for-sale-in-karachi-9803858
#
# Scraping: https://www.pakwheels.com/used-cars/toyota-pixis-epoch-2020-for-sale-in-karachi-9784519
#
# Scraped Car Details:
# Model: Toyota Pixis Epoch X 2020 for sale in Karachi
# Price (Lacs): 35.0
# Price (PKR): 3500000
# Currency: PKR
# Location: Toyota Pixis Epoch X 2020  Used for sale  in Karachi for PKR 35.0 lacs <span></span>. Buy this 660 cc, Red 43958 KM Driven, Automatic Car. Contact Seller Now!
# Listing URL: https://www.pakwheels.com/used-cars/toyota-pixis-epoch-2020-for-sale-in-karachi-9784519
#
# Scraping: https://www.pakwheels.com/used-cars/suzuki-cultus-2016-for-sale-in-karachi-9746005
#
# Scraped Car Details:
# Model: Suzuki Cultus Limited Edition 2016 for sale in Karachi
# Price (Lacs): 17.4
# Price (PKR): 1739999
# Currency: PKR
# Location: Suzuki Cultus Limited Edition 2016  Used for sale  in Karachi for PKR 17.4 lacs <span></span>. Buy this 1000 cc, Silver 60142 KM Driven, Manual Car. Contact Seller Now!
# Listing URL: https://www.pakwheels.com/used-cars/suzuki-cultus-2016-for-sale-in-karachi-9746005
#
# Scraping: https://www.pakwheels.com/used-cars/daihatsu-cuore-2010-for-sale-in-karachi-9784962
#
# Scraped Car Details:
# Model: Daihatsu Cuore CX Automatic 2010 for sale in Karachi
# Price (Lacs): 13.0
# Price (PKR): 1300000
# Currency: PKR
# Location: Daihatsu Cuore CX Automatic 2010  Used for sale  in Karachi for PKR 13.0 lacs <span></span>. Buy this 800 cc, Unlisted 161972 KM Driven, Automatic Car. Contact Seller Now!
# Listing URL: https://www.pakwheels.com/used-cars/daihatsu-cuore-2010-for-sale-in-karachi-9784962
#
# Scraping: https://www.pakwheels.com/used-cars/toyota-corolla-2019-for-sale-in-lahore-9784582
#
# Scraped Car Details:
# Model: Toyota Corolla Altis Grande CVT-i 1.8 2019 for sale in Lahore
# Price (Lacs): 53.5
# Price (PKR): 5350000
# Currency: PKR
# Location: Toyota Corolla Altis Grande CVT-i 1.8 2019  Used for sale  in Lahore for PKR 53.5 lacs <span></span>. Buy this 1800 cc, Black 116057 KM Driven, Automatic Car. Contact Seller Now!
# Listing URL: https://www.pakwheels.com/used-cars/toyota-corolla-2019-for-sale-in-lahore-9784582
#
# Scraping: https://www.pakwheels.com/used-cars/suzuki-jimny-2020-for-sale-in-karachi-9706602
#
# Scraped Car Details:
# Model: Suzuki Jimny GA MT 2020 for sale in Karachi
# Price (Lacs): 62.0
# Price (PKR): 6200000
# Currency: PKR
# Location: Suzuki Jimny GA MT 2020  Used for sale  in Karachi for PKR 62.0 lacs <span></span>. Buy this 1500 cc, Yellow 36729 KM Driven, Manual Car. Contact Seller Now!
# Listing URL: https://www.pakwheels.com/used-cars/suzuki-jimny-2020-for-sale-in-karachi-9706602
#
# Scraping: https://www.pakwheels.com/used-cars/mg-hs-2021-for-sale-in-lahore-9795246
#
# Scraped Car Details:
# Model: MG HS Trophy 2021 for sale in Lahore
# Price (Lacs): 63.0
# Price (PKR): 6300000
# Currency: PKR
# Location: MG HS Trophy 2021  Used for sale  in Lahore for PKR 63.0 lacs <span></span>. Buy this 1500 cc, Black 66121 KM Driven, Automatic Car. Contact Seller Now!
# Listing URL: https://www.pakwheels.com/used-cars/mg-hs-2021-for-sale-in-lahore-9795246
#
# Scraping: https://www.pakwheels.com/used-cars/suzuki-spacia-2015-for-sale-in-lahore-9745121
#
# Scraped Car Details:
# Model: Suzuki Spacia 2015 for sale in Lahore
# Price (Lacs): 22.0
# Price (PKR): 2200000
# Currency: PKR
# Location: Suzuki Spacia 2015  Used for sale  in Lahore for PKR 22.0 lacs <span></span>. Buy this 660 cc, White 105744 KM Driven, Automatic Car. Contact Seller Now!
# Listing URL: https://www.pakwheels.com/used-cars/suzuki-spacia-2015-for-sale-in-lahore-9745121
#
# Scraping: https://www.pakwheels.com/used-cars/daihatsu-tanto-2021-for-sale-in-karachi-9803870
#
# Scraped Car Details:
# Model: Daihatsu Tanto 2021 for sale in Karachi
# Price (Lacs): 30.5
# Price (PKR): 3050000
# Currency: PKR
# Location: Daihatsu Tanto 2021  Used for sale  in Karachi for PKR 30.5 lacs <span></span>. Buy this 660 cc, White 79919 KM Driven, Automatic Car. Contact Seller Now!
# Listing URL: https://www.pakwheels.com/used-cars/daihatsu-tanto-2021-for-sale-in-karachi-9803870
#
# Scraping: https://www.pakwheels.com/used-cars/daihatsu-gran-max-2011-for-sale-in-karachi-9651801
#
# Scraped Car Details:
# Model: Daihatsu Gran Max MT 2011 for sale in Karachi
# Price (Lacs): 19.5
# Price (PKR): 1950000
# Currency: PKR
# Location: Daihatsu Gran Max MT 2011  Used for sale  in Karachi for PKR 19.5 lacs <span></span>. Buy this 1500 cc, Silver 177151 KM Driven, Manual Car. Contact Seller Now!
# Listing URL: https://www.pakwheels.com/used-cars/daihatsu-gran-max-2011-for-sale-in-karachi-9651801
#
# Scraping: https://www.pakwheels.com/used-cars/daihatsu-mira-2021-for-sale-in-karachi-9782751
#
# Scraped Car Details:
# Model: Daihatsu Mira X SA lll 2021 for sale in Karachi
# Price (Lacs): 37.0
# Price (PKR): 3700000
# Currency: PKR
# Location: Daihatsu Mira X SA lll 2021  Used for sale  in Karachi for PKR 37.0 lacs <span></span>. Buy this 660 cc, Unlisted 39474 KM Driven, Automatic Car. Contact Seller Now!
# Listing URL: https://www.pakwheels.com/used-cars/daihatsu-mira-2021-for-sale-in-karachi-9782751
#
# Scraping: https://www.pakwheels.com/used-cars/toyota-corolla-2019-for-sale-in-gujranwala-9745699
#
# Scraped Car Details:
# Model: Toyota Corolla Altis Automatic 1.6 2019 for sale in Gujranwala
# Price (Lacs): 46.5
# Price (PKR): 4650000
# Currency: PKR
# Location: Toyota Corolla Altis Automatic 1.6 2019  Used for sale  in Gujranwala for PKR 46.5 lacs <span></span>. Buy this 1600 cc, Black 50971 KM Driven, Automatic Car. Contact Seller Now!
# Listing URL: https://www.pakwheels.com/used-cars/toyota-corolla-2019-for-sale-in-gujranwala-9745699
#
# Scraping: https://www.pakwheels.com/used-cars/lexus-lx-series-2015-for-sale-in-karachi-9803843
#
# Scraped Car Details:
# Model: Lexus LX Series LX570 2015 for sale in Karachi
# Price (Lacs):
# Price (PKR):
# Currency:
# Location: Lexus LX Series LX570 2015  Used for sale  in Karachi. Buy this 5700 cc, Black 124000 KM Driven, Automatic Car. Contact Seller Now!
# Listing URL: https://www.pakwheels.com/used-cars/lexus-lx-series-2015-for-sale-in-karachi-9803843
#
# Scraping: https://www.pakwheels.com/used-cars/toyota-c-hr-2019-for-sale-in-gujranwala-9707003
#
# Scraped Car Details:
# Model: Toyota C-HR G-LED 2019 for sale in Gujranwala
# Price (Lacs): 88.0
# Price (PKR): 8800000
# Currency: PKR
# Location: Toyota C-HR G-LED 2019  Used for sale  in Gujranwala for PKR 88.0 lacs <span></span>. Buy this 1800 cc, White 63713 KM Driven, Automatic Car. Contact Seller Now!
# Listing URL: https://www.pakwheels.com/used-cars/toyota-c-hr-2019-for-sale-in-gujranwala-9707003
#
# ✅ Data saved to scraped_cars.csv
